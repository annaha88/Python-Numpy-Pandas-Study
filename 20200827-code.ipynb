# %%
import numpy as np
import pandas as pd

# %%
data = {
        'Name':['Chumlmin','Eunkyung','Jinwoong','Soobeom']
       ,'Year':[2011,2016,2015,2015]
       ,'Gender':['Male','Female','Male','Male']  
       }
data
# Out:
# {'Name': ['Chumlmin', 'Eunkyung', 'Jinwoong', 'Soobeom'],
#  'Year': [2011, 2016, 2015, 2015],
#  'Gender': ['Male', 'Female', 'Male', 'Male']}

# %%
indexes = ['one','two','three','four']

data_df = pd.DataFrame(data, index = indexes)

data_df
# Out:
#            Name  Year  Gender
# one    Chumlmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
data_df.iloc[[0,3],[1,2]]
# Out:
#       Year Gender
# one   2011   Male
# four  2015   Male

# %%
data_df_reset=data_df.reset_index()
data_df_reset.index = data_df_reset.index +1
data_df_reset=data_df_reset.rename(columns={'index' :'old index'})
data_df_reset
# Out:
#   old index      Name  Year  Gender
# 1       one  Chumlmin  2011    Male
# 2       two  Eunkyung  2016  Female
# 3     three  Jinwoong  2015    Male
# 4      four   Soobeom  2015    Male

# %%
data_df_reset.iloc[[1,3],[1]]
# Out:
#        Name
# 2  Eunkyung
# 4   Soobeom

# %%
a = data_df.loc[['one', 'three'],['Name']]
type(a)
a
# Out:
#            Name
# one    Chumlmin
# three  Jinwoong

# %%
b= data_df.loc['one','Name']
type(b)
b
# Out:
# 'Chumlmin'

# %%
data_df.loc['one':'three', ['Name']]
# Out:
#            Name
# one    Chumlmin
# two    Eunkyung
# three  Jinwoong

# %%
data_df.iloc[0:2,0:2]
# Out:
#          Name  Year
# one  Chumlmin  2011
# two  Eunkyung  2016

# %%
data_df_reset
# Out:
#   old index      Name  Year  Gender
# 1       one  Chumlmin  2011    Male
# 2       two  Eunkyung  2016  Female
# 3     three  Jinwoong  2015    Male
# 4      four   Soobeom  2015    Male

# %%
data_df_reset.loc[2:3,'old index':'Year']
# Out:
#   old index      Name  Year
# 2       two  Eunkyung  2016
# 3     three  Jinwoong  2015

# %%
titanic_df = pd.read_csv('./data/titanic_train.csv')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic_df[['Age','Fare','Pclass']]
# Out:
#       Age     Fare  Pclass
# 0    22.0   7.2500       3
# 1    38.0  71.2833       1
# 2    26.0   7.9250       3
# 3    35.0  53.1000       1
# 4    35.0   8.0500       3
# ..    ...      ...     ...
# 886  27.0  13.0000       2
# 887  19.0  30.0000       1
# 888   NaN  23.4500       3
# 889  26.0  30.0000       1
# 890  32.0   7.7500       3
#
# [891 rows x 3 columns]

# %%
bool = titanic_df['Age']> 60
bool
type(bool)
# Out:
# pandas.core.series.Series

# %%
print(bool)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic_df[bool&(titanic_df['Pclass']==1)&(titanic_df['Sex']=='female')][['Age','Pclass','Sex']]
# Out:
#       Age  Pclass     Sex
# 275  63.0       1  female
# 829  62.0       1  female

# %%
type(titanic_df['Age']>60)
# Out:
# pandas.core.series.Series

# %%
(titanic_df['Age']>60).values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
# ...

# %%
#나이 60이상 데이터 추출
titanic_boolean = titanic_df[titanic_df['Age']>60]
titanic_boolean.head(3)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 33           34         0       2           Wheadon, Mr. Edward H  male  66.0
# 54           55         0       1  Ostby, Mr. Engelhart Cornelius  male  65.0
# 96           97         0       1       Goldschmidt, Mr. George B  male  71.0
#
#     SibSp  Parch      Ticket     Fare Cabin Embarked
# 33      0      0  C.A. 24579  10.5000   NaN        S
# 54      0      1      113509  61.9792   B30        C
# 96      0      0    PC 17754  34.6542    A5        C

# %%
titanic_boolean[['PassengerId','Age','Sex']].head(3)
# Out:
#     PassengerId   Age   Sex
# 33           34  66.0  male
# 54           55  65.0  male
# 96           97  71.0  male

# %%
titanic_df[(titanic_df['Age']>60)|(titanic_df['Sex']=='male')][['Age','Sex','Name']].head(5)
# Out:
#     Age   Sex                            Name
# 0  22.0  male         Braund, Mr. Owen Harris
# 4  35.0  male        Allen, Mr. William Henry
# 5   NaN  male                Moran, Mr. James
# 6  54.0  male         McCarthy, Mr. Timothy J
# 7   2.0  male  Palsson, Master. Gosta Leonard

# %%
#DataFrame[Row][Col]
#DataFrame[Row,Col] => 명기반 추출 => loc[Row, Col]

titanic_df.loc[
   (titanic_df['Age']>60)&(titanic_df['Sex']=='male')
  , ['Name','Age']
].head(3)
# Out:
#                               Name   Age
# 33           Wheadon, Mr. Edward H  66.0
# 54  Ostby, Mr. Engelhart Cornelius  65.0
# 96       Goldschmidt, Mr. George B  71.0

# %%
# 다중 조건 추출
# 논리 연산자 사용(and &, or |, not ~)
# 문제 : 나이가 60 잉상이고, 선실등급 1등급, 성별이 여성인 승객 추출

titanic_df[
             (titanic_df['Age']>60)
           & (titanic_df['Pclass']==1)
           & (titanic_df['Sex']=='female')
        ] 
[['Name']]
# Out:
#                                           Name
# 275          Andrews, Miss. Kornelia Theodosia
# 829  Stone, Mrs. George Nelson (Martha Evelyn)

# %%
cond1 = titanic_df['Age']>60
cond2 = titanic_df['Pclass']==1
cond3 = titanic_df['Sex']=='female'

titanic_df[cond1&cond2&cond3][['Name','Ticket']]
# Out:
#                                           Name  Ticket
# 275          Andrews, Miss. Kornelia Theodosia   13502
# 829  Stone, Mrs. George Nelson (Martha Evelyn)  113572

# %%
# 고정인자 방식
def titanic_search(age, pclass, sex):
        c1 = titanic_df['Age']> age
        c2 = titanic_df['Pclass']== pclass
        c3 = titanic_df['Sex']== sex
        return titanic_df[c1&c2&c3]

# %%
titanic_search(40,3,'female').head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 132          133         0       3
# 167          168         0       3
# 254          255         0       3
# 276          277         0       3
# 362          363         0       3
# 483          484         1       3
# 638          639         0       3
# 678          679         0       3
# 736          737         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 132   Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0      1
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 254         Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.0      0
# 276                Lindblom, Miss. Augusta Charlotta  female  45.0      0
# 362                  Barbara, Mrs. (Catherine David)  female  45.0      0
# 483                           Turkula, Mrs. (Hedwig)  female  63.0      0
# 638           Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0      0
# ...

# %%
def titanic_search(*args):         #*args 가변 인자 만들때
#        c1 = titanic_df['Age']> age
#        c2 = titanic_df['Pclass']== pclass
#        c3 = titanic_df['Sex']== sex
#        return titanic_df[c1&c2&c3]

# %%
def titanic_search(*args):
        #처리 코드 삽입
        c1 = titanic_df['Age']> age
        c2 = titanic_df['Pclass']== pclass
        c3 = titanic_df['Sex']== sex
    return titanic_df[c1&c2&c3]

# %%
# **args: 딕셔너리 가변인자 처리
def titanic_search(**args):
    #처리 코드 삽입
    return titanic_df[c1&c2&c3]

# %%
# 고정인자 방식, 디폴트값 줄수도 있다.
def titanic_search(age, pclass=1, sex='male'):
        c1 = titanic_df['Age']> age
        c2 = titanic_df['Pclass']== pclass
        c3 = titanic_df['Sex']== sex
        return titanic_df[c1&c2&c3]

# %%
titanic_search(20,3)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0              1         0       3       Braund, Mr. Owen Harris  male  22.0
# 4              5         0       3      Allen, Mr. William Henry  male  35.0
# 13            14         0       3   Andersson, Mr. Anders Johan  male  39.0
# 37            38         0       3      Cann, Mr. Ernest Charles  male  21.0
# 51            52         0       3  Nosworthy, Mr. Richard Cater  male  21.0
# ..           ...       ...     ...                           ...   ...   ...
# 870          871         0       3             Balkic, Mr. Cerin  male  26.0
# 873          874         0       3   Vander Cruyssen, Mr. Victor  male  47.0
# 881          882         0       3            Markun, Mr. Johann  male  33.0
# 884          885         0       3        Sutehall, Mr. Henry Jr  male  25.0
# 890          891         0       3           Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
titanic_sorted = titanic_df.sort_values(by=['Pclass','Name'])
titanic_sorted.sort_values(by=['Name'], inplace=True)
titanic_sorted
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
# 집계(Aggregation => agg) 함수 적용
a=titanic_df.count()
type(a)
# Out:
# pandas.core.series.Series

# %%
titanic_df[['Survived','Age']].mean()
# Out:
# Survived     0.383838
# Age         29.699118
# dtype: float64

# %%
print(a.values)
print(a.index)
# Out:
# [891 891 891 891 891 714 891 891 891 891 204 889]
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_groupby=titanic_df.groupby('Pclass')[['Survived','Age']].sum()
titanic_groupby
# Out:
#         Survived      Age
# Pclass
# 1            136  7111.42
# 2             87  5168.83
# 3            119  8924.92

# %%
titanic_groupby = titanic_df.groupby('Pclass')[['Age','Fare','Survived']].agg([max,min,sum])[['Age']]
a = titanic_groupby
a
# Out:
#          Age
#          max   min      sum
# Pclass
# 1       80.0  0.92  7111.42
# 2       70.0  0.67  5168.83
# 3       74.0  0.42  8924.92

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.loc[2,min]
# Out:
# 70.0

# %%
agg_format={'Age':'max','SibSp':'sum','Fare':'mean'}
titanic_df.groupby('Pclass').agg(agg_format)
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %%
titanic_boolean = titanic_df['Age']>60
type(titanic_boolean)
# Out:
# pandas.core.series.Series

# %%
titanic_df[titanic_boolean][['Name','Sex']]
# Out:
#                                           Name     Sex
# 33                       Wheadon, Mr. Edward H    male
# 54              Ostby, Mr. Engelhart Cornelius    male
# 96                   Goldschmidt, Mr. George B    male
# 116                       Connors, Mr. Patrick    male
# 170                  Van der hoef, Mr. Wyckoff    male
# 252                  Stead, Mr. William Thomas    male
# 275          Andrews, Miss. Kornelia Theodosia  female
# 280                           Duane, Mr. Frank    male
# 326                  Nysveen, Mr. Johan Hansen    male
# 438                          Fortune, Mr. Mark    male
# 456                  Millet, Mr. Francis Davis    male
# 483                     Turkula, Mrs. (Hedwig)  female
# 493                    Artagaveytia, Mr. Ramon    male
# 545               Nicholson, Mr. Arthur Ernest    male
# 555                         Wright, Mr. George    male
# 570                         Harris, Mr. George    male
# ...

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.loc[titanic_boolean,['Name','Age']].sort_values(by=['Age'])
# Out:
#                                           Name   Age
# 625                      Sutton, Mr. Frederick  61.0
# 170                  Van der hoef, Mr. Wyckoff  61.0
# 326                  Nysveen, Mr. Johan Hansen  61.0
# 570                         Harris, Mr. George  62.0
# 252                  Stead, Mr. William Thomas  62.0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)  62.0
# 555                         Wright, Mr. George  62.0
# 275          Andrews, Miss. Kornelia Theodosia  63.0
# 483                     Turkula, Mrs. (Hedwig)  63.0
# 438                          Fortune, Mr. Mark  64.0
# 545               Nicholson, Mr. Arthur Ernest  64.0
# 456                  Millet, Mr. Francis Davis  65.0
# 54              Ostby, Mr. Engelhart Cornelius  65.0
# 280                           Duane, Mr. Frank  65.0
# 33                       Wheadon, Mr. Edward H  66.0
# 672                Mitchell, Mr. Henry Michael  70.0
# 745               Crosby, Capt. Edward Gifford  70.0
# ...

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.groupby('Pclass').agg([max,min])[['PassengerId','Age','Name']]
# Out:
#        PassengerId       Age                               Name  \
#                max min   max   min                          max
# Pclass
# 1              890   2  80.0  0.92     Young, Miss. Marie Grice
# 2              887  10  70.0  0.67    del Carlo, Mr. Sebastiano
# 3              891   1  74.0  0.42  van Melkebeke, Mr. Philemon
#
#
#                                   min
# Pclass
# 1       Allen, Miss. Elisabeth Walton
# 2                 Abelson, Mr. Samuel
# 3                 Abbing, Mr. Anthony

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a= titanic_df.loc[(titanic_df['Embarked']=='C')&(titanic_df['Sex']=='female'), 'Name':'Ticket'].sort_values(['Age']).groupby('Ticket')

# %%
type(a)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
a.agg({'Age':'max','Parch':'mean','SibSp':'min'}).sort_values('Age')
# Out:
#                   Age  Parch  SibSp
# Ticket
# 2653              1.0    2.0      0
# 349256            4.0    1.0      0
# 2678              9.0    1.5      0
# 2687             13.0    0.0      0
# 2651             14.0    0.0      1
# 237736           14.0    0.0      1
# 2665             14.5    0.0      1
# 2659             15.0    0.0      1
# 2667             15.0    0.0      0
# SC 1748          17.0    0.0      0
# 2627             17.0    0.0      0
# PC 17758         17.0    0.0      1
# 11967            19.0    0.0      1
# PC 17608         21.0    2.0      2
# 13568            22.0    2.0      0
# SC/Paris 2123    22.0    2.0      1
# SC/AH Basle 541  23.0    0.0      0
# PC 17482         24.0    0.0      0
# PC 17477         24.0    0.0      0
# 2666             24.0    1.5      0
# SC/PARIS 2149    27.0    0.0      1
# P/PP 3381        28.0    0.0      1
# 2650             29.0    2.0      0
# PC 17761         30.0    0.0      0
# 113798           30.0    0.0      0
# ...
