# %%
import numpy as np
import pandas as pd

# %%
list1 = [1,2,3]
arr1 = np.array(list1)
arr1
# Out:
# array([1, 2, 3])

# %%
arr1.shape
# Out:
# (3,)

# %%
df_list1 = pd.DataFrame(list1)
df_arr1 = pd.DataFrame(arr1)
print(df_arr1)
print(df_list1)
# Out:
#    0
# 0  1
# 1  2
# 2  3
#    0
# 0  1
# 1  2
# 2  3

# %%
df_list1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df_arr1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df_list1.columns = ['kor']

# %%
df_list1
# Out:
#    kor
# 0    1
# 1    2
# 2    3

# %%
a = df_list1.columns
a
# Out:
# Index(['kor'], dtype='object')

# %%
print(pd.__version__)
# Out:
# 1.1.0

# %%
type(a)
# Out:
# pandas.core.indexes.base.Index

# %%
df_arr1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df_arr1.columns = ['eng']

# %%
df_arr1
# Out:
#    eng
# 0    1
# 1    2
# 2    3

# %%
df_arr1

# %%
# 2차원 데이터셋으로 DataFrame 생성
list2 = [
    [1,  2,  3]
  , [11,12, 13]
]
list2
# Out:
# [[1, 2, 3], [11, 12, 13]]

# %%
df_list2 = pd.DataFrame(list2)
df_list2
# Out:
#     0   1   2
# 0   1   2   3
# 1  11  12  13

# %%
df_list2.columns=['kor','eng','mat']

# %%
df_list2
# Out:
#    kor  eng  mat
# 0    1    2    3
# 1   11   12   13

# %%
dict_= {
     'kor':[1,11]
    ,'eng':[2,12]
    ,'mat':[3,13]
}
dict_
# Out:
# {'kor': [1, 11], 'eng': [2, 12], 'mat': [3, 13]}

# %%
df_dict_ = pd.DataFrame(dict_)
df_dict_
# Out:
#    kor  eng  mat
# 0    1    2    3
# 1   11   12   13

# %%
arr3 = df_dict_.values
arr3
# Out:
# array([[ 1,  2,  3],
#        [11, 12, 13]], dtype=int64)

# %%
type(arr3)
# Out:
# numpy.ndarray

# %%
id(arr3)
# Out:
# 2802391344992

# %%
arr3.shape
# Out:
# (2, 3)

# %%
arr3.ndim
# Out:
# 2

# %%
# DataFrame => list 로 변환
# df_dict_ : DataFrame
# df_dict.values : ndarray
# df_dict.values.tolist() : list
list3 = df_dict_.values.tolist()
list3
# Out:
# [[1, 2, 3], [11, 12, 13]]

# %%
type(list3)
# Out:
# list

# %%
# DataFrame => Dict 로 변환
dict3 = df_dict_.to_dict()
dict3
# Out:
# {'kor': {0: 1, 1: 11}, 'eng': {0: 2, 1: 12}, 'mat': {0: 3, 1: 13}}

# %%
dict4 = df_dict_.to_dict('list')
dict4
# Out:
# {'kor': [1, 11], 'eng': [2, 12], 'mat': [3, 13]}

# %%
titanic_df = pd.read_csv(
    r'./data/titanic_train.csv'
)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a = titanic_df.columns

# %%
a
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# DataFrame 에 컬럼 추가, 수정
# 1. dict 형식 이용하는 방식
# 2. 소유(.) 이용하는 방식
# Out:
# {'a': 1, 'b': 2}

# %%
d1 = {'a':1,'b':2}
d1

d1['c'] = [1,2,3]
d1['d'] = {1,2,3}
d1['e'] = {1:2, 2:3,3:4}
d1
# Out:
# {'a': 1, 'b': 2, 'c': [1, 2, 3], 'd': {1, 2, 3}, 'e': {1: 2, 2: 3, 3: 4}}

# %%
titanic_df['Age_0'] = list(range(1,892))
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# titanic_df['컬럼명'] => 컬럼에 있는 데이터 확인
# value 는 ndarray 에 저장되어 있다.
# ndarray 는 루프 없이 반복된다. 
titanic_df['Age_0']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: Age_0, Length: 891, dtype: int64

# %%
# 브로드 캐스팅 예제
list5 = [
    [1,2]
  , [3,4]
]
list5
# Out:
# [[1, 2], [3, 4]]

# %%
arr_list5= np.array(list5)
arr_list5
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2 = arr_list5*10
arr2
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
arr2.ndim
# Out:
# 2

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['Family_No'] = titanic_df['SibSp'] + titanic_df['Parch']+1

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df = titanic_df.drop(('Age_0','Embarked_0'), axis = 1)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df2 = titanic_df.drop([])
# Out:
#   File "<ipython-input-128-8210ecef019f>", line 1
#     titanic_df2 = titanic_df.drop([7:10])
#                                     ^
# SyntaxError: invalid syntax

# %%
titanic_df2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked  Family_No
# 0      0  A/5 21171   7.2500   NaN        S          2
# 1      0   PC 17599  71.2833   C85        C          2
# 5      0     330877   8.4583   NaN        Q          1

# %%
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family_No
# 0      0         A/5 21171   7.2500   NaN        S          2
# 1      0          PC 17599  71.2833   C85        C          2
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1
